# %%
# !f2py -c -m  gsmoothall ../kfas/src/gsmoothall.f90
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "gsmoothall" sources
# f2py options: []
# f2py:> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9
# Reading fortran codes...
# 	Reading file '../kfas/src/gsmoothall.f90' (format:free)
# Post-processing...
# 	Block: gsmoothall
# 			Block: gsmoothall
# Post-processing (stage 2)...
# Building modules...
# 	Building module "gsmoothall"...
# 		Constructing wrapper function "gsmoothall"...
# 		  gsmoothall(ymiss,timevar,zt,ht,tt,rtv,qt,j,at,pt,vt,ft,kt,rt,rt0,rt1,nt,nt0,nt1,nt2,pinf,kinf,finf,ahat,vvt,epshat,epshatvar,etahat,etahatvar,thetahat,thetahatvar,ldlsignal,zorig,zorigtv,aug,state,dist,signal,[p,n,m,r,d])
# 	Wrote C/API module "gsmoothall" to file "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c"
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/fortranobject.c' to sources.
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9' to include_dirs.
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.c -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.h -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
# customize Gnu95FCompiler
# Found executable /usr/local/bin/gfortran
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'gsmoothall' extension
# compiling C sources
# C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/usr/local/opt/openssl@1.1/include
#
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders/js
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9
# compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/fortranobject.c
# In file included from In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/fortranobject.c::162:
# :
# In file included from In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/fortranobject.h/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/fortranobject.h::1313:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h::44:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h::1212:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h::19691969:
# :
# /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h::1717::22::  warningwarning: :
#       "Using
# deprecated       "UsingNumPy  deprecatedAPI,  NumPydisable  API,it  disablewith  it"          "#define
# with       NPY_NO_DEPRECATED_API"          "#define
# NPY_1_7_API_VERSION"       NPY_NO_DEPRECATED_API[-W#warnings] NPY_1_7_API_VERSION"
#  [-W#warnings]
# #warning "Using deprecated NumPy API, disable it with " \
# #warning "Using deprecated NumPy API, disable it with " \
#  ^
#  ^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c:527:40: error:
#       called object type 'int *' is not a function or function pointer
#   zt_Dims[0]=p,zt_Dims[2]=(n-1)*timevar(1)+1;
#                                 ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c:539:53: error:
#       called object type 'int *' is not a function or function pointer
#   ht_Dims[0]=p,ht_Dims[1]=p,ht_Dims[2]=(n-1)*timevar(2)+1;
#                                              ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c:628:53: error:
#       called object type 'int *' is not a function or function pointer
#   tt_Dims[0]=m,tt_Dims[1]=m,tt_Dims[2]=(n-1)*timevar(3)+1;
#                                              ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c:640:42: error:
#       called object type 'int *' is not a function or function pointer
#   rtv_Dims[0]=m,rtv_Dims[2]=(n-1)*timevar(4)+1;
#                                   ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c:770:53: error:
#       called object type 'int *' is not a function or function pointer
#   qt_Dims[0]=r,qt_Dims[1]=r,qt_Dims[2]=(n-1)*timevar(5)+1;
#                                              ~~~~~~~^
# 1 warning and 5 errors generated.
# 1 warning generated.
# error: Command "clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/usr/local/opt/openssl@1.1/include -DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.c -o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.o -MMD -MF /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpp8upg3xf/src.macosx-10.15-x86_64-3.9/gsmoothallmodule.o.d" failed with exit status 1

# %%
# !ls
# Out:
# data                         moddata.f90
# euclidian_norm.f90           notebook.Rproj
# kfas-local-level.R           run_KFS.ipynb
# moddata.cpython-39-darwin.so use_f2py.ipynb

# %% [markdown]
# ## Compile only params definition
#
# ... Fails because `timevar()` in `dimension(p,m,(n-1)*timevar(1)+1)` is regarded as a function

# %%
# %%file gsmoothparams.f90
# ! Subroutine for Kalman smoothing of linear gaussian state space model
#
# subroutine gsmoothparams(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
# rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
# etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#
#     implicit none
#
#     integer, intent(in) :: d, j, p, r, m, n,aug,state,dist,signal,ldlsignal,zorigtv
#     integer :: t, i, k1, k2
#     integer, intent(in), dimension(n,p) :: ymiss
#     integer, intent(in), dimension(5) :: timevar
#     double precision, intent(in), dimension(p,m,(n-1)*timevar(1)+1) :: zt
#     double precision, intent(in), dimension(p,p,(n-1)*timevar(2)+1) :: ht
#     double precision, intent(in), dimension(m,m,(n-1)*timevar(3)+1) :: tt
#     double precision, intent(in), dimension(m,r,(n-1)*timevar(4)+1) :: rtv
#     double precision, intent(in), dimension(r,r,(n-1)*timevar(5)+1) :: qt
#     double precision, intent(in), dimension(m,n+1) :: at
#     double precision, intent(in), dimension(m,m,n+1) :: pt
#     double precision, intent(in), dimension(p,n) ::  vt,ft
#     double precision, intent(in), dimension(m,p,n) :: kt
#     double precision, intent(in), dimension(m,m,d+1) ::  pinf
#     double precision, intent(in),dimension(m,p,d) ::  kinf
#     double precision, intent(in), dimension(p,d) ::  finf
#     double precision, intent(inout), dimension(m,m,n+1) :: nt !n_1 = n_0, ..., n_201 = n_200
#     double precision, intent(inout), dimension(m,n+1) :: rt !same as n, r_1 = r_0 etc.
#     double precision, intent(inout), dimension(m,d+1) :: rt0,rt1
#     double precision, intent(inout), dimension(m,m,d+1) :: nt0,nt1,nt2
#     double precision, intent(inout), dimension(m*state,n*state) :: ahat
#     double precision, intent(inout), dimension(m,m,n) :: vvt
#     double precision, intent(inout), dimension(p*dist*aug,n*dist*aug) :: epshat
#     double precision, intent(inout), dimension(p*dist*aug,n*dist*aug) :: epshatvar
#     double precision, intent(inout), dimension(r*dist,n*dist) :: etahat
#     double precision, intent(inout), dimension(r*dist,r*dist,n*dist) :: etahatvar
#     double precision, intent(inout), dimension(p*signal,n*signal) :: thetahat
#     double precision, intent(inout), dimension(p*signal,p*signal,n*signal) :: thetahatvar
#     double precision, intent(in), dimension(ldlsignal*p,ldlsignal*m,ldlsignal*((n-1)*zorigtv+1)) :: zorig
#     double precision, dimension(m,m) :: linf,l0
#     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#     double precision, dimension(m) :: rrec,rrec1,rhelp, help
#     double precision, dimension(m,r) :: mr, mr2
#     double precision, dimension(p,m) :: pm
#     double precision, dimension(p,n) ::  ftinv
#     double precision, dimension(p,d) ::  finfinv
#     double precision, external :: ddot
#     external dgemm, dsymm, dgemv, dsymv, dger
#
# end subroutine gsmoothparams
# Out:
# Overwriting gsmoothparams.f90

# %%
# !f2py -c -m gsmoothparams gsmoothparams.f90
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "gsmoothparams" sources
# f2py options: []
# f2py:> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9
# Reading fortran codes...
# 	Reading file 'gsmoothparams.f90' (format:free)
# Post-processing...
# 	Block: gsmoothparams
# 			Block: gsmoothparams
# Post-processing (stage 2)...
# Building modules...
# 	Building module "gsmoothparams"...
# 		Constructing wrapper function "gsmoothparams"...
# 		  gsmoothparams(ymiss,timevar,zt,ht,tt,rtv,qt,j,at,pt,vt,ft,kt,rt,rt0,rt1,nt,nt0,nt1,nt2,pinf,kinf,finf,ahat,vvt,epshat,epshatvar,etahat,etahatvar,thetahat,thetahatvar,ldlsignal,zorig,zorigtv,aug,state,dist,signal,[p,n,m,r,d])
# 	Wrote C/API module "gsmoothparams" to file "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c"
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/fortranobject.c' to sources.
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9' to include_dirs.
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.c -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.h -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
# customize Gnu95FCompiler
# Found executable /usr/local/bin/gfortran
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'gsmoothparams' extension
# compiling C sources
# C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/usr/local/opt/openssl@1.1/include
#
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders/js
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9
# compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/fortranobject.c
# In file included from In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/fortranobject.c/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c::216:
# :
# In file included from In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/fortranobject.h/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/fortranobject.h::1313:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h::44:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h::1212:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h::19691969:
# :
# /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h::1717::22::  warningwarning: :
#
#             "Using"Using  deprecateddeprecated  NumPyNumPy  API,API,  disabledisable  itit  withwith  "          "#define"          "#define
#
#             NPY_NO_DEPRECATED_APINPY_NO_DEPRECATED_API  NPY_1_7_API_VERSION"NPY_1_7_API_VERSION"  [-W#warnings][-W#warnings]
#
# #warning "Using deprecated NumPy API, disable it with " \#warning "Using deprecated NumPy API, disable it with " \
#
#  ^ ^
#
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c:527:40: error:
#       called object type 'int *' is not a function or function pointer
#   zt_Dims[0]=p,zt_Dims[2]=(n-1)*timevar(1)+1;
#                                 ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c:539:53: error:
#       called object type 'int *' is not a function or function pointer
#   ht_Dims[0]=p,ht_Dims[1]=p,ht_Dims[2]=(n-1)*timevar(2)+1;
#                                              ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c:628:53: error:
#       called object type 'int *' is not a function or function pointer
#   tt_Dims[0]=m,tt_Dims[1]=m,tt_Dims[2]=(n-1)*timevar(3)+1;
#                                              ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c:640:42: error:
#       called object type 'int *' is not a function or function pointer
#   rtv_Dims[0]=m,rtv_Dims[2]=(n-1)*timevar(4)+1;
#                                   ~~~~~~~^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c:770:53: error:
#       called object type 'int *' is not a function or function pointer
#   qt_Dims[0]=r,qt_Dims[1]=r,qt_Dims[2]=(n-1)*timevar(5)+1;
#                                              ~~~~~~~^
# 1 warning and 5 errors generated.
# 1 warning generated.
# error: Command "clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/usr/local/opt/openssl@1.1/include -DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.c -o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.o -MMD -MF /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpe9ro2g4g/src.macosx-10.15-x86_64-3.9/gsmoothparamsmodule.o.d" failed with exit status 1

# %% [markdown]
# ## minimum subroutine
#
# ... Compiling succeeded by annotation

# %%
# %%file ztdef.f90
# subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#
#     implicit none
#
#     integer, intent(in) :: p, m, n, dist, aug
#     integer, intent(in), dimension(5) :: timevar
#     double precision, intent(in), dimension(:,:,:) :: zt
#     !f2py depend(timevar) dimension(p,m,(n-1)*timevar(1)+1)
#
# end subroutine ztdef
# Out:
# Overwriting ztdef.f90

# %%
# !f2py -c -m ztdef ztdef.f90
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "ztdef" sources
# f2py options: []
# f2py:> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdefmodule.c
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9
# Reading fortran codes...
# 	Reading file 'ztdef.f90' (format:free)
# Post-processing...
# 	Block: ztdef
# 			Block: ztdef
# Post-processing (stage 2)...
# Building modules...
# 	Building module "ztdef"...
# 		Creating wrapper for Fortran subroutine "ztdef"("ztdef")...
# 		Constructing wrapper function "ztdef"...
# 		  ztdef(timevar,zt,p,n,m,dist,aug)
# 	Wrote C/API module "ztdef" to file "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdefmodule.c"
# 	Fortran 90 wrappers are saved to "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdef-f2pywrappers2.f90"
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/fortranobject.c' to sources.
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9' to include_dirs.
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.c -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.h -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdef-f2pywrappers2.f90' to sources.
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
# customize Gnu95FCompiler
# Found executable /usr/local/bin/gfortran
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'ztdef' extension
# compiling C sources
# C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/usr/local/opt/openssl@1.1/include
#
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9
# compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdefmodule.c
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/fortranobject.c
# In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdefmodule.c:16:
# In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/fortranobject.h:13:
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969:
# /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning:
#       "Using deprecated NumPy API, disable it with "          "#define
#       NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# In file included from #warning "Using deprecated NumPy API, disable it with " \
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/fortranobject.c: ^2
# :
# In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/fortranobject.h:13:
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969:
# /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning:
#       "Using deprecated NumPy API, disable it with "          "#define
#       NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it with " \
#  ^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdefmodule.c:137:12: warning:
#       unused function 'f2py_size' [-Wunused-function]
# static int f2py_size(PyArrayObject* var, ...)
#            ^
# 2 warnings generated.
# 1 warning generated.
# compiling Fortran sources
# Fortran f77 compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/local/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# gfortran:f90: ztdef.f90
# f951: Warning: Nonexistent include directory '/Users/tatamiya/Documents/pykfas-dev/.venv/include' [-Wmissing-include-dirs]
# ztdef.f90:1:48:
#
#     1 | subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#       |                                                1
# Warning: Unused dummy argument 'aug' at (1) [-Wunused-dummy-argument]
# ztdef.f90:1:43:
#
#     1 | subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#       |                                           1
# Warning: Unused dummy argument 'dist' at (1) [-Wunused-dummy-argument]
# ztdef.f90:1:37:
#
#     1 | subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#       |                                     1
# Warning: Unused dummy argument 'm' at (1) [-Wunused-dummy-argument]
# ztdef.f90:1:34:
#
#     1 | subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#       |                                  1
# Warning: Unused dummy argument 'n' at (1) [-Wunused-dummy-argument]
# ztdef.f90:1:31:
#
#     1 | subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#       |                               1
# Warning: Unused dummy argument 'p' at (1) [-Wunused-dummy-argument]
# ztdef.f90:1:24:
#
#     1 | subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#       |                        1
# Warning: Unused dummy argument 'timevar' at (1) [-Wunused-dummy-argument]
# ztdef.f90:1:28:
#
#     1 | subroutine ztdef(timevar, zt, p, n, m, dist, aug)
#       |                            1
# Warning: Unused dummy argument 'zt' at (1) [-Wunused-dummy-argument]
# gfortran:f90: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdef-f2pywrappers2.f90
# f951: Warning: Nonexistent include directory '/Users/tatamiya/Documents/pykfas-dev/.venv/include' [-Wmissing-include-dirs]
# /usr/local/bin/gfortran -Wall -g -Wall -g -undefined dynamic_lookup -bundle -L/usr/local/opt/openssl@1.1/lib /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdefmodule.o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/fortranobject.o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/ztdef.o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh/src.macosx-10.15-x86_64-3.9/ztdef-f2pywrappers2.o -L/usr/local/Cellar/gcc/10.2.0_2/lib/gcc/10/gcc/x86_64-apple-darwin19/10.2.0 -L/usr/local/Cellar/gcc/10.2.0_2/lib/gcc/10/gcc/x86_64-apple-darwin19/10.2.0/../../.. -L/usr/local/Cellar/gcc/10.2.0_2/lib/gcc/10/gcc/x86_64-apple-darwin19/10.2.0/../../.. -lgfortran -o ./ztdef.cpython-39-darwin.so
# Removing build directory /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpubdgu5zh

# %%
import ztdef

# %%
print(ztdef.ztdef.__doc__)
# Out:
# ztdef(timevar,zt,m,vt,ft,dist,aug,epshat,[p,n])
#
# Wrapper for ``ztdef``.
#
# Parameters
# ----------
# timevar : input rank-1 array('i') with bounds (5)
# zt : input rank-3 array('d') with bounds (f2py_zt_d0,f2py_zt_d1,f2py_zt_d2)
# m : input int
# vt : input rank-2 array('d') with bounds (p,n)
# ft : input rank-2 array('d') with bounds (p,n)
# dist : input int
# aug : input int
# epshat : in/output rank-2 array('d') with bounds (p*dist*aug,n*dist*aug)
#
# Other Parameters
# ----------------
# p : input int, optional
#     Default: shape(vt,0)
# n : input int, optional
#     Default: shape(vt,1)

# %% [markdown]
# ## Add annotations on `timevar`
#
# ... Still fails because `p` is regarded as REAL for some unknown reason.

# %%
# %%file gsmooth_timevar_annotated.f90
# ! Subroutine for Kalman smoothing of linear gaussian state space model
#
# subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
# rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
# etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#
#     implicit none
#
#     integer, intent(in) :: d, j, p, r, m, n
#     integer, intent(in) :: aug,state,dist,signal,ldlsignal,zorigtv
#     integer :: t, i, k1, k2
#     integer, intent(in), dimension(n,p) :: ymiss
#     integer, intent(in), dimension(5) :: timevar
#     double precision, intent(in), dimension(:,:,:) :: zt
#     !f2py depend(timevar) dimension(p,m,(n-1)*timevar(1)+1)
#     double precision, intent(in), dimension(:,:,:) :: ht
#     !f2py depend(timevar) dimension(p,p,(n-1)*timevar(2)+1)
#     double precision, intent(in), dimension(:,:,:) :: tt
#     !f2py depend(timevar) dimension(m,m,(n-1)*timevar(3)+1)
#     double precision, intent(in), dimension(:,:,:) :: rtv
#     !f2py depend(timevar) dimension(m,r,(n-1)*timevar(4)+1)
#     double precision, intent(in), dimension(:,:,:) :: qt
#     !f2py depend(timevar) dimension(r,r,(n-1)*timevar(5)+1)
#     double precision, intent(in), dimension(m,n+1) :: at
#     double precision, intent(in), dimension(m,m,n+1) :: pt
#     double precision, intent(in), dimension(p,n) ::  vt,ft
#     double precision, intent(in), dimension(m,p,n) :: kt
#     double precision, intent(in), dimension(m,m,d+1) ::  pinf
#     double precision, intent(in),dimension(m,p,d) ::  kinf
#     double precision, intent(in), dimension(p,d) ::  finf
#     double precision, intent(inout), dimension(m,m,n+1) :: nt !n_1 = n_0, ..., n_201 = n_200
#     double precision, intent(inout), dimension(m,n+1) :: rt !same as n, r_1 = r_0 etc.
#     double precision, intent(inout), dimension(m,d+1) :: rt0,rt1
#     double precision, intent(inout), dimension(m,m,d+1) :: nt0,nt1,nt2
#     double precision, intent(inout), dimension(m*state,n*state) :: ahat
#     double precision, intent(inout), dimension(m,m,n) :: vvt
#     double precision, intent(inout), dimension(p*dist*aug,n*dist*aug) :: epshat
#     double precision, intent(inout), dimension(p*dist*aug,n*dist*aug) :: epshatvar
#     double precision, intent(inout), dimension(r*dist,n*dist) :: etahat
#     double precision, intent(inout), dimension(r*dist,r*dist,n*dist) :: etahatvar
#     double precision, intent(inout), dimension(p*signal,n*signal) :: thetahat
#     double precision, intent(inout), dimension(p*signal,p*signal,n*signal) :: thetahatvar
#     double precision, intent(in), dimension(ldlsignal*p,ldlsignal*m,ldlsignal*((n-1)*zorigtv+1)) :: zorig
#     double precision, dimension(m,m) :: linf,l0
#     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#     double precision, dimension(m) :: rrec,rrec1,rhelp, help
#     double precision, dimension(m,r) :: mr, mr2
#     double precision, dimension(p,m) :: pm
#     double precision, dimension(p,n) ::  ftinv
#     double precision, dimension(p,d) ::  finfinv
#     double precision, external :: ddot
#     external dgemm, dsymm, dgemv, dsymv, dger
#
# end subroutine timevarannotated
# Out:
# Writing gsmooth_timevar_annotated.f90

# %%
# !f2py -c -m timevarannotated gsmooth_timevar_annotated.f90
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "timevarannotated" sources
# f2py options: []
# f2py:> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotatedmodule.c
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9
# Reading fortran codes...
# 	Reading file 'gsmooth_timevar_annotated.f90' (format:free)
# Post-processing...
# 	Block: timevarannotated
# 			Block: timevarannotated
# Post-processing (stage 2)...
# Building modules...
# 	Building module "timevarannotated"...
# 		Creating wrapper for Fortran subroutine "timevarannotated"("timevarannotated")...
# 		Constructing wrapper function "timevarannotated"...
# 		  timevarannotated(ymiss,timevar,zt,ht,tt,rtv,qt,r,j,at,pt,vt,ft,kt,rt,rt0,rt1,nt,nt0,nt1,nt2,pinf,kinf,finf,ahat,vvt,epshat,epshatvar,etahat,etahatvar,thetahat,thetahatvar,ldlsignal,zorig,zorigtv,aug,state,dist,signal,[p,n,m,d])
# 	Wrote C/API module "timevarannotated" to file "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotatedmodule.c"
# 	Fortran 90 wrappers are saved to "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90"
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/fortranobject.c' to sources.
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9' to include_dirs.
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.c -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.h -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90' to sources.
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
# customize Gnu95FCompiler
# Found executable /usr/local/bin/gfortran
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'timevarannotated' extension
# compiling C sources
# C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/usr/local/opt/openssl@1.1/include
#
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var/folders
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var/folders/js
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9
# compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotatedmodule.c
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/fortranobject.c
# In file included from In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/fortranobject.c/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotatedmodule.c::216:
# :
# In file included from In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/fortranobject.h/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/fortranobject.h::1313:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h::44:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h::1212:
# :
# In file included from In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h::19691969:
# :
# /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h::1717::22::  warningwarning: :
#
#             "Using"Using  deprecateddeprecated  NumPyNumPy  API,API,  disabledisable  itit  withwith  "          "#define"          "#define
#
#             NPY_NO_DEPRECATED_APINPY_NO_DEPRECATED_API  NPY_1_7_API_VERSION"NPY_1_7_API_VERSION"  [-W#warnings][-W#warnings]
#
# #warning "Using deprecated NumPy API, disable it with " \#warning "Using deprecated NumPy API, disable it with " \
#
#  ^ ^
#
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotatedmodule.c:144:12: warning:
#       unused function 'f2py_size' [-Wunused-function]
# static int f2py_size(PyArrayObject* var, ...)
#            ^
# 1 warning generated.
# 2 warnings generated.
# compiling Fortran sources
# Fortran f77 compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/local/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# gfortran:f90: gsmooth_timevar_annotated.f90
# f951: Warning: Nonexistent include directory '/Users/tatamiya/Documents/pykfas-dev/.venv/include' [-Wmissing-include-dirs]
# gsmooth_timevar_annotated.f90:4:54:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                                                      1
# Warning: Unused dummy argument 'ahat' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:83:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                                                   1
# Warning: Unused dummy argument 'at' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:66:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                                                                  1
# Warning: Unused dummy argument 'epshat' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:76:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                                                                            1
# Warning: Unused dummy argument 'epshatvar' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:5:6:
#
#     5 | etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#       |      1
# Warning: Unused dummy argument 'etahat' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:5:16:
#
#     5 | etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#       |                1
# Warning: Unused dummy argument 'etahatvar' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:48:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                                                1
# Warning: Unused dummy argument 'finf' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:50:48:
#
#    50 |     double precision, dimension(p,d) ::  finfinv
#       |                                                1
# Warning: Unused variable 'finfinv' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:3:95:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                                                               1
# Warning: Unused dummy argument 'ft' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:49:46:
#
#    49 |     double precision, dimension(p,n) ::  ftinv
#       |                                              1
# Warning: Unused variable 'ftinv' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:46:60:
#
#    46 |     double precision, dimension(m) :: rrec,rrec1,rhelp, help
#       |                                                            1
# Warning: Unused variable 'help' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:3:50:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                  1
# Warning: Unused dummy argument 'ht' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:11:19:
#
#    11 |     integer :: t, i, k1, k2
#       |                   1
# Warning: Unused variable 'i' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:45:59:
#
#    45 |     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#       |                                                           1
# Warning: Unused variable 'im' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:3:79:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                                               1
# Warning: Unused dummy argument 'j' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:11:23:
#
#    11 |     integer :: t, i, k1, k2
#       |                       1
# Warning: Unused variable 'k1' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:11:27:
#
#    11 |     integer :: t, i, k1, k2
#       |                           1
# Warning: Unused variable 'k2' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:4:43:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                                           1
# Warning: Unused dummy argument 'kinf' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:99:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                                                                   1
# Warning: Unused dummy argument 'kt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:44:47:
#
#    44 |     double precision, dimension(m,m) :: linf,l0
#       |                                               1
# Warning: Unused variable 'l0' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:44:44:
#
#    44 |     double precision, dimension(m,m) :: linf,l0
#       |                                            1
# Warning: Unused variable 'linf' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:45:62:
#
#    45 |     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#       |                                                              1
# Warning: Unused variable 'mm' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:45:66:
#
#    45 |     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#       |                                                                  1
# Warning: Unused variable 'mm2' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:47:42:
#
#    47 |     double precision, dimension(m,r) :: mr, mr2
#       |                                          1
# Warning: Unused variable 'mr' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:47:47:
#
#    47 |     double precision, dimension(m,r) :: mr, mr2
#       |                                               1
# Warning: Unused variable 'mr2' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:45:44:
#
#    45 |     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#       |                                            1
# Warning: Unused variable 'nrec' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:45:50:
#
#    45 |     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#       |                                                  1
# Warning: Unused variable 'nrec1' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:45:56:
#
#    45 |     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#       |                                                        1
# Warning: Unused variable 'nrec2' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:4:16:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                1
# Warning: Unused dummy argument 'nt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:21:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                     1
# Warning: Unused dummy argument 'nt0' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:26:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                          1
# Warning: Unused dummy argument 'nt1' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:31:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                               1
# Warning: Unused dummy argument 'nt2' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:37:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                                     1
# Warning: Unused dummy argument 'pinf' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:48:42:
#
#    48 |     double precision, dimension(p,m) :: pm
#       |                                          1
# Warning: Unused variable 'pm' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:3:87:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                                                       1
# Warning: Unused dummy argument 'pt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:62:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                              1
# Warning: Unused dummy argument 'qt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:46:54:
#
#    46 |     double precision, dimension(m) :: rrec,rrec1,rhelp, help
#       |                                                      1
# Warning: Unused variable 'rhelp' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:46:42:
#
#    46 |     double precision, dimension(m) :: rrec,rrec1,rhelp, help
#       |                                          1
# Warning: Unused variable 'rrec' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:46:48:
#
#    46 |     double precision, dimension(m) :: rrec,rrec1,rhelp, help
#       |                                                1
# Warning: Unused variable 'rrec1' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:4:2:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |  1
# Warning: Unused dummy argument 'rt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:7:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |       1
# Warning: Unused dummy argument 'rt0' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:12:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |            1
# Warning: Unused dummy argument 'rt1' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:58:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                          1
# Warning: Unused dummy argument 'rtv' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:11:16:
#
#    11 |     integer :: t, i, k1, k2
#       |                1
# Warning: Unused variable 't' declared at (1) [-Wunused-variable]
# gsmooth_timevar_annotated.f90:5:25:
#
#     5 | etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#       |                         1
# Warning: Unused dummy argument 'thetahat' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:5:37:
#
#     5 | etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#       |                                     1
# Warning: Unused dummy argument 'thetahatvar' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:42:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                          1
# Warning: Unused dummy argument 'timevar' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:53:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                     1
# Warning: Unused dummy argument 'tt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:91:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                                                                           1
# Warning: Unused dummy argument 'vt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:4:59:
#
#     4 | rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
#       |                                                           1
# Warning: Unused dummy argument 'vvt' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:33:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                 1
# Warning: Unused dummy argument 'ymiss' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:5:54:
#
#     5 | etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#       |                                                      1
# Warning: Unused dummy argument 'zorig' at (1) [-Wunused-dummy-argument]
# gsmooth_timevar_annotated.f90:3:46:
#
#     3 | subroutine timevarannotated(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
#       |                                              1
# Warning: Unused dummy argument 'zt' at (1) [-Wunused-dummy-argument]
# gfortran:f90: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90
# f951: Warning: Nonexistent include directory '/Users/tatamiya/Documents/pykfas-dev/.venv/include' [-Wmissing-include-dirs]
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:85:40:
#
#    85 |                 integer, intent(in) :: p
#       |                                        1
# Error: Symbol 'p' at (1) already has basic type of REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:127:46:
#
#   127 |                 integer, intent(in) :: zorigtv
#       |                                              1
# Error: Symbol 'zorigtv' at (1) already has basic type of REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:128:42:
#
#   128 |                 integer, intent(in) :: aug
#       |                                          1
# Error: Symbol 'aug' at (1) already has basic type of REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:129:44:
#
#   129 |                 integer, intent(in) :: state
#       |                                            1
# Error: Symbol 'state' at (1) already has basic type of REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:130:43:
#
#   130 |                 integer, intent(in) :: dist
#       |                                           1
# Error: Symbol 'dist' at (1) already has basic type of REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:131:45:
#
#   131 |                 integer, intent(in) :: signal
#       |                                             1
# Error: Symbol 'signal' at (1) already has basic type of REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:78:48:
#
#    78 |                 integer, intent(in),dimension(n,p) :: ymiss
#       |                                                1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:93:55:
#
#    93 |                 double precision, intent(in),dimension(p,n) :: vt
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:94:55:
#
#    94 |                 double precision, intent(in),dimension(p,n) :: ft
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:95:57:
#
#    95 |                 double precision, intent(in),dimension(m,p,n) :: kt
#       |                                                         1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:107:57:
#
#   107 |                 double precision, intent(in),dimension(m,p,d) :: kinf
#       |                                                         1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:108:55:
#
#   108 |                 double precision, intent(in),dimension(p,d) :: finf
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:109:58:
#
#   109 |                 double precision, intent(inout),dimension(m*state,n*stat&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:112:58:
#
#   112 |                 double precision, intent(inout),dimension(p*dist*aug,n*d&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:114:58:
#
#   114 |                 double precision, intent(inout),dimension(p*dist*aug,n*d&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:116:58:
#
#   116 |                 double precision, intent(inout),dimension(r*dist,n*dist)&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:118:58:
#
#   118 |                 double precision, intent(inout),dimension(r*dist,r*dist,&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:120:58:
#
#   120 |                 double precision, intent(inout),dimension(p*signal,n*sig&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:122:58:
#
#   122 |                 double precision, intent(inout),dimension(p*signal,p*sig&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:125:55:
#
#   125 |                 double precision, intent(in),dimension(ldlsignal*p,ldlsi&
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:78:48:
#
#    78 |                 integer, intent(in),dimension(n,p) :: ymiss
#       |                                                1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:93:55:
#
#    93 |                 double precision, intent(in),dimension(p,n) :: vt
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:94:55:
#
#    94 |                 double precision, intent(in),dimension(p,n) :: ft
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:95:57:
#
#    95 |                 double precision, intent(in),dimension(m,p,n) :: kt
#       |                                                         1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:107:57:
#
#   107 |                 double precision, intent(in),dimension(m,p,d) :: kinf
#       |                                                         1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:108:55:
#
#   108 |                 double precision, intent(in),dimension(p,d) :: finf
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:109:58:
#
#   109 |                 double precision, intent(inout),dimension(m*state,n*stat&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:112:58:
#
#   112 |                 double precision, intent(inout),dimension(p*dist*aug,n*d&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:114:58:
#
#   114 |                 double precision, intent(inout),dimension(p*dist*aug,n*d&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:116:58:
#
#   116 |                 double precision, intent(inout),dimension(r*dist,n*dist)&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:118:58:
#
#   118 |                 double precision, intent(inout),dimension(r*dist,r*dist,&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:120:58:
#
#   120 |                 double precision, intent(inout),dimension(p*signal,n*sig&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:122:58:
#
#   122 |                 double precision, intent(inout),dimension(p*signal,p*sig&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:125:55:
#
#   125 |                 double precision, intent(in),dimension(ldlsignal*p,ldlsi&
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:109:58:
#
#   109 |                 double precision, intent(inout),dimension(m*state,n*stat&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:112:58:
#
#   112 |                 double precision, intent(inout),dimension(p*dist*aug,n*d&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:114:58:
#
#   114 |                 double precision, intent(inout),dimension(p*dist*aug,n*d&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:116:58:
#
#   116 |                 double precision, intent(inout),dimension(r*dist,n*dist)&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:118:58:
#
#   118 |                 double precision, intent(inout),dimension(r*dist,r*dist,&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:108:55:
#
#   108 |                 double precision, intent(in),dimension(p,d) :: finf
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:94:55:
#
#    94 |                 double precision, intent(in),dimension(p,n) :: ft
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:107:57:
#
#   107 |                 double precision, intent(in),dimension(m,p,d) :: kinf
#       |                                                         1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:95:57:
#
#    95 |                 double precision, intent(in),dimension(m,p,n) :: kt
#       |                                                         1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:120:58:
#
#   120 |                 double precision, intent(inout),dimension(p*signal,n*sig&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:122:58:
#
#   122 |                 double precision, intent(inout),dimension(p*signal,p*sig&
#       |                                                          1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:93:55:
#
#    93 |                 double precision, intent(in),dimension(p,n) :: vt
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:78:48:
#
#    78 |                 integer, intent(in),dimension(n,p) :: ymiss
#       |                                                1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:125:55:
#
#   125 |                 double precision, intent(in),dimension(ldlsignal*p,ldlsi&
#       |                                                       1
# Error: Expression at (1) must be of INTEGER type, found REAL
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90:138:14:
#
#   138 |      & signal)
#       |              1
# Error: Type mismatch in argument 'p' at (1); passed INTEGER(4) to REAL(4)
# error: Command "/usr/local/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c -c /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.f90 -o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmpq4jraecv/src.macosx-10.15-x86_64-3.9/timevarannotated-f2pywrappers2.o" failed with exit status 1

# %% [markdown]
# ## Add decrease params one by one
#
# ... Found that compiling succeeds if no other parameter definition uses `p`

# %%
# %%file decrease_params.f90
# ! Subroutine for Kalman smoothing of linear gaussian state space model
#
# subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
# pinf,&
# ldlsignal, zorigtv,aug,state,dist,signal)
#
#     implicit none
#
#     integer, intent(in) :: d, j, p, r, m, n
#     integer, intent(in) :: aug,state,dist,signal,ldlsignal,zorigtv
#     integer :: t, i, k1, k2
#     integer, intent(in), dimension(:,:) :: ymiss
#     !f2py depend(p) dimension(n,p)
#     integer, intent(in), dimension(5) :: timevar
#     double precision, intent(in), dimension(:,:,:) :: zt
#     !f2py depend(timevar) dimension(p,m,(n-1)*timevar(1)+1)
#     double precision, intent(in), dimension(:,:,:) :: ht
#     !f2py depend(timevar) dimension(p,p,(n-1)*timevar(2)+1)
#     double precision, intent(in), dimension(:,:,:) :: tt
#     !f2py depend(timevar) dimension(m,m,(n-1)*timevar(3)+1)
#     double precision, intent(in), dimension(:,:,:) :: rtv
#     !f2py depend(timevar) dimension(m,r,(n-1)*timevar(4)+1)
#     double precision, intent(in), dimension(:,:,:) :: qt
#     !f2py depend(timevar) dimension(r,r,(n-1)*timevar(5)+1)
#     double precision, intent(in), dimension(m,n+1) :: at
#     double precision, intent(in), dimension(m,m,n+1) :: pt
#     double precision, intent(in), dimension(:,:) ::  vt,ft
#     !f2py depend(p) dimension(p,n)
#     !double precision, intent(in), dimension(m,p,n) :: kt
#     double precision, intent(in), dimension(m,m,d+1) ::  pinf
#     !double precision, intent(in),dimension(m,p,d) ::  kinf
#     !double precision, intent(in), dimension(p,d) ::  finf
#     !double precision, intent(inout), dimension(m,m,n+1) :: nt !n_1 = n_0, ..., n_201 = n_200
#     !double precision, intent(inout), dimension(m,n+1) :: rt !same as n, r_1 = r_0 etc.
#     !double precision, intent(inout), dimension(m,d+1) :: rt0,rt1
#     !double precision, intent(inout), dimension(m,m,d+1) :: nt0,nt1,nt2
#     !double precision, intent(inout), dimension(m*state,n*state) :: ahat
#     !double precision, intent(inout), dimension(m,m,n) :: vvt
#     !double precision, intent(inout), dimension(p*dist*aug,n*dist*aug) :: epshat
#     !double precision, intent(inout), dimension(p*dist*aug,n*dist*aug) :: epshatvar
#     !double precision, intent(inout), dimension(r*dist,n*dist) :: etahat
#     !double precision, intent(inout), dimension(r*dist,r*dist,n*dist) :: etahatvar
#     !double precision, intent(inout), dimension(p*signal,n*signal) :: thetahat
#     !double precision, intent(inout), dimension(p*signal,p*signal,n*signal) :: thetahatvar
#     !double precision, intent(in), dimension(ldlsignal*p,ldlsignal*m,ldlsignal*((n-1)*zorigtv+1)) :: zorig
#
# end subroutine decrease_params
# Out:
# Overwriting decrease_params.f90

# %%
# !f2py -c -m decreaseparams decrease_params.f90
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "decreaseparams" sources
# f2py options: []
# f2py:> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparamsmodule.c
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9
# Reading fortran codes...
# 	Reading file 'decrease_params.f90' (format:free)
# Post-processing...
# 	Block: decreaseparams
# 			Block: decrease_params
# Post-processing (stage 2)...
# Building modules...
# 	Building module "decreaseparams"...
# 		Creating wrapper for Fortran subroutine "decrease_params"("decrease_params")...
# 		Constructing wrapper function "decrease_params"...
# 		  decrease_params(ymiss,timevar,vt,ft,zt,ht,tt,rtv,qt,p,r,j,at,pt,pinf,ldlsignal,zorigtv,aug,state,dist,signal,[n,m,d])
# 	Wrote C/API module "decreaseparams" to file "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparamsmodule.c"
# 	Fortran 90 wrappers are saved to "/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparams-f2pywrappers2.f90"
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/fortranobject.c' to sources.
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9' to include_dirs.
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.c -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9
# copying /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/f2py/src/fortranobject.h -> /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9
#   adding '/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparams-f2pywrappers2.f90' to sources.
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
# customize Gnu95FCompiler
# Found executable /usr/local/bin/gfortran
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'decreaseparams' extension
# compiling C sources
# C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include -I/usr/local/opt/openssl@1.1/include
#
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai
# creating /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9
# compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparamsmodule.c
# clang: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/fortranobject.c
# In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparamsmodule.c:16:
# In file included from /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/fortranobject.h:In file included from 13:
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/fortranobject.cIn file included from :/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h2::
# 4In file included from :
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/fortranobject.hIn file included from :/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h13::
# 12In file included from :
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h::41969:
# :
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
# In file included from /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h::196917:
# :2: warning: /Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:
# 17      :"Using2 :deprecated  NumPy warningAPI,:  disable it
# with       "Using"          "#define
# deprecated       NPY_NO_DEPRECATED_APINumPy API,  disable it with "          "#define
#       NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]NPY_1_7_API_VERSION"
#  [-W#warnings]
# #warning "Using deprecated NumPy API, disable it with " \
#  ^
# #warning "Using deprecated NumPy API, disable it with " \
#  ^
# /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparamsmodule.c:144:12: warning:
#       unused function 'f2py_size' [-Wunused-function]
# static int f2py_size(PyArrayObject* var, ...)
#            ^
# 2 warnings generated.
# 1 warning generated.
# compiling Fortran sources
# Fortran f77 compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/local/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/local/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9 -I/Users/tatamiya/Documents/pykfas-dev/.venv/lib/python3.9/site-packages/numpy/core/include -I/Users/tatamiya/Documents/pykfas-dev/.venv/include -I/Users/tatamiya/.pyenv/versions/3.9.1/include/python3.9 -c'
# gfortran:f90: decrease_params.f90
# f951: Warning: Nonexistent include directory '/Users/tatamiya/Documents/pykfas-dev/.venv/include' [-Wmissing-include-dirs]
# decrease_params.f90:3:88:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                                                        1
# Warning: Unused dummy argument 'at' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:5:22:
#
#     5 | ldlsignal, zorigtv,aug,state,dist,signal)
#       |                      1
# Warning: Unused dummy argument 'aug' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:5:33:
#
#     5 | ldlsignal, zorigtv,aug,state,dist,signal)
#       |                                 1
# Warning: Unused dummy argument 'dist' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:48:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                1
# Warning: Unused dummy argument 'ft' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:55:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                       1
# Warning: Unused dummy argument 'ht' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:11:19:
#
#    11 |     integer :: t, i, k1, k2
#       |                   1
# Warning: Unused variable 'i' declared at (1) [-Wunused-variable]
# decrease_params.f90:3:84:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                                                    1
# Warning: Unused dummy argument 'j' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:11:23:
#
#    11 |     integer :: t, i, k1, k2
#       |                       1
# Warning: Unused variable 'k1' declared at (1) [-Wunused-variable]
# decrease_params.f90:11:27:
#
#    11 |     integer :: t, i, k1, k2
#       |                           1
# Warning: Unused variable 'k2' declared at (1) [-Wunused-variable]
# decrease_params.f90:5:9:
#
#     5 | ldlsignal, zorigtv,aug,state,dist,signal)
#       |         1
# Warning: Unused dummy argument 'ldlsignal' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:70:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                                      1
# Warning: Unused dummy argument 'p' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:4:4:
#
#     4 | pinf,&
#       |    1
# Warning: Unused dummy argument 'pinf' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:92:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                                                            1
# Warning: Unused dummy argument 'pt' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:67:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                                   1
# Warning: Unused dummy argument 'qt' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:79:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                                               1
# Warning: Unused dummy argument 'r' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:63:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                               1
# Warning: Unused dummy argument 'rtv' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:5:40:
#
#     5 | ldlsignal, zorigtv,aug,state,dist,signal)
#       |                                        1
# Warning: Unused dummy argument 'signal' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:5:28:
#
#     5 | ldlsignal, zorigtv,aug,state,dist,signal)
#       |                            1
# Warning: Unused dummy argument 'state' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:11:16:
#
#    11 |     integer :: t, i, k1, k2
#       |                1
# Warning: Unused variable 't' declared at (1) [-Wunused-variable]
# decrease_params.f90:3:41:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                         1
# Warning: Unused dummy argument 'timevar' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:58:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                          1
# Warning: Unused dummy argument 'tt' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:45:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                             1
# Warning: Unused dummy argument 'vt' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:32:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                1
# Warning: Unused dummy argument 'ymiss' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:5:18:
#
#     5 | ldlsignal, zorigtv,aug,state,dist,signal)
#       |                  1
# Warning: Unused dummy argument 'zorigtv' at (1) [-Wunused-dummy-argument]
# decrease_params.f90:3:51:
#
#     3 | subroutine decrease_params(ymiss, timevar, vt,ft,zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, &
#       |                                                   1
# Warning: Unused dummy argument 'zt' at (1) [-Wunused-dummy-argument]
# gfortran:f90: /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparams-f2pywrappers2.f90
# f951: Warning: Nonexistent include directory '/Users/tatamiya/Documents/pykfas-dev/.venv/include' [-Wmissing-include-dirs]
# f951: Warning: '&' not allowed by itself in line 61
# /usr/local/bin/gfortran -Wall -g -Wall -g -undefined dynamic_lookup -bundle -L/usr/local/opt/openssl@1.1/lib /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparamsmodule.o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/fortranobject.o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/decrease_params.o /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai/src.macosx-10.15-x86_64-3.9/decreaseparams-f2pywrappers2.o -L/usr/local/Cellar/gcc/10.2.0_2/lib/gcc/10/gcc/x86_64-apple-darwin19/10.2.0 -L/usr/local/Cellar/gcc/10.2.0_2/lib/gcc/10/gcc/x86_64-apple-darwin19/10.2.0/../../.. -L/usr/local/Cellar/gcc/10.2.0_2/lib/gcc/10/gcc/x86_64-apple-darwin19/10.2.0/../../.. -lgfortran -o ./decreaseparams.cpython-39-darwin.so
# Removing build directory /var/folders/js/n4rh779x3gd78qnzrpf58b540000gn/T/tmponuf_bai

# %%
# !ls -la
# Out:
# total 880
# drwxr-xr-x  19 tatamiya  staff     608  9 26 14:40 .
# drwxr-xr-x  12 tatamiya  staff     384  9 25 18:27 ..
# drwxr-xr-x   4 tatamiya  staff     128  9 24 17:23 .Rproj.user
# drwxr-xr-x   4 tatamiya  staff     128  9 25 16:18 .ipynb_checkpoints
# drwxr-xr-x   3 tatamiya  staff      96  9 24 17:19 data
# -rw-r--r--   1 tatamiya  staff    2629  9 26 14:40 decrease_params.f90
# -rwxr-xr-x   1 tatamiya  staff   46652  9 26 14:40 decreaseparams.cpython-39-darwin.so
# -rw-r--r--   1 tatamiya  staff     147  9 22 18:31 euclidian_norm.f90
# -rwxr-xr-x   1 tatamiya  staff   38316  9 26 12:50 f2pysample.cpython-39-darwin.so
# -rw-r--r--   1 tatamiya  staff    3255  9 26 14:34 gsmoothparams.f90
# -rw-r--r--   1 tatamiya  staff    1137  9 25 16:46 kfas-local-level.R
# -rwxr-xr-x   1 tatamiya  staff   38636  9 22 18:35 moddata.cpython-39-darwin.so
# -rw-r--r--   1 tatamiya  staff     422  9 22 18:33 moddata.f90
# -rw-r--r--   1 tatamiya  staff     205  9 24 17:24 notebook.Rproj
# -rw-r--r--   1 tatamiya  staff  156672  9 26 14:40 run_KFS.ipynb
# -rw-r--r--   1 tatamiya  staff     325  9 26 12:50 sample.f90
# -rw-r--r--   1 tatamiya  staff   84883  9 22 20:18 use_f2py.ipynb
# -rwxr-xr-x   1 tatamiya  staff   38164  9 26 12:58 ztdef.cpython-39-darwin.so
# -rw-r--r--   1 tatamiya  staff     505  9 26 12:58 ztdef.f90

# %%
import decreaseparams

# %%
print(decreaseparams.decrease_params.__doc__)
# Out:
# decrease_params(timevar,zt,ht,tt,rtv,qt,p,r,j,at,pt,pinf,ldlsignal,zorigtv,aug,state,dist,signal,[n,m,d])
#
# Wrapper for ``decrease_params``.
#
# Parameters
# ----------
# timevar : input rank-1 array('i') with bounds (5)
# zt : input rank-3 array('d') with bounds (f2py_zt_d0,f2py_zt_d1,f2py_zt_d2)
# ht : input rank-3 array('d') with bounds (f2py_ht_d0,f2py_ht_d1,f2py_ht_d2)
# tt : input rank-3 array('d') with bounds (f2py_tt_d0,f2py_tt_d1,f2py_tt_d2)
# rtv : input rank-3 array('d') with bounds (f2py_rtv_d0,f2py_rtv_d1,f2py_rtv_d2)
# qt : input rank-3 array('d') with bounds (f2py_qt_d0,f2py_qt_d1,f2py_qt_d2)
# p : input int
# r : input int
# j : input int
# at : input rank-2 array('d') with bounds (m,n + 1)
# pt : input rank-3 array('d') with bounds (m,m,n + 1)
# pinf : input rank-3 array('d') with bounds (m,m,d + 1)
# ldlsignal : input int
# zorigtv : input int
# aug : input int
# state : input int
# dist : input int
# signal : input int
#
# Other Parameters
# ----------------
# n : input int, optional
#     Default: (shape(at,1)-1)
# m : input int, optional
#     Default: shape(at,0)
# d : input int, optional
#     Default: (shape(pinf,2)-1)

# %% [markdown]
# ## Add annotation one by one until compile succeeds

# %%
# !cat ../kfas/src/gsmoothall.f90
# Out:
# ! Subroutine for Kalman smoothing of linear gaussian state space model
#
# subroutine gsmoothall(ymiss, timevar, zt, ht,tt, rtv, qt, p, n, m, r, d,j, at, pt, vt, ft, kt, &
# rt, rt0, rt1, nt, nt0, nt1, nt2, pinf, kinf,finf ,ahat, vvt,epshat,epshatvar, &
# etahat,etahatvar,thetahat,thetahatvar, ldlsignal,zorig, zorigtv,aug,state,dist,signal)
#
#     implicit none
#
#     integer, intent(in) :: d, j, p, r, m, n,aug,state,dist,signal,ldlsignal,zorigtv
#     integer :: t, i, k1, k2
#     integer, intent(in), dimension(:,:) :: ymiss
#     !f2py depend(p) dimension(n,p)
#     integer, intent(in), dimension(5) :: timevar
#     double precision, intent(in), dimension(:,:,:) :: zt
#     !f2py depend(timevar) dimension(p,m,(n-1)*timevar(1)+1)
#     double precision, intent(in), dimension(:,:,:) :: ht
#     !f2py depend(timevar) dimension(p,p,(n-1)*timevar(2)+1)
#     double precision, intent(in), dimension(:,:,:) :: tt
#     !f2py depend(timevar) dimension(m,m,(n-1)*timevar(3)+1)
#     double precision, intent(in), dimension(:,:,:) :: rtv
#     !f2py depend(timevar) dimension(m,r,(n-1)*timevar(4)+1)
#     double precision, intent(in), dimension(:,:,:) :: qt
#     !f2py depend(timevar) dimension(r,r,(n-1)*timevar(5)+1)
#     double precision, intent(in), dimension(m,n+1) :: at
#     double precision, intent(in), dimension(m,m,n+1) :: pt
#     double precision, intent(in), dimension(:,:) ::  vt,ft
#     !f2py depend(p) dimension(p,n)
#     double precision, intent(in), dimension(:,:,:) :: kt
#     !f2py depend(p) dimension(m,p,n)
#     double precision, intent(in), dimension(m,m,d+1) ::  pinf
#     double precision, intent(in),dimension(:,:,:) ::  kinf
#     !f2py depend(p) dimension(m,p,d)
#     double precision, intent(in), dimension(:,:) ::  finf
#     !f2py depend(p) dimension(p,d)
#     double precision, intent(inout), dimension(m,m,n+1) :: nt !n_1 = n_0, ..., n_201 = n_200
#     double precision, intent(inout), dimension(m,n+1) :: rt !same as n, r_1 = r_0 etc.
#     double precision, intent(inout), dimension(m,d+1) :: rt0,rt1
#     double precision, intent(inout), dimension(m,m,d+1) :: nt0,nt1,nt2
#     double precision, intent(inout), dimension(:,:) :: ahat
#     !f2py depend(state) dimension(m*state,n*state)
#     double precision, intent(inout), dimension(m,m,n) :: vvt
#     double precision, intent(inout), dimension(:,:) :: epshat
#     !f2py depend(p) dimension(p*dist*aug,n*dist*aug)
#     double precision, intent(inout), dimension(:,:) :: epshatvar
#     !f2py depend(p) dimension(p*dist*aug,n*dist*aug)
#     double precision, intent(inout), dimension(:,:) :: etahat
#     !f2py depend(dist) dimension(r*dist,n*dist)
#     double precision, intent(inout), dimension(:,:,:) :: etahatvar
#     !f2py depend(dist) dimension(r*dist,r*dist,n*dist)
#     double precision, intent(inout), dimension(:,:) :: thetahat
#     !f2py depend(p) dimension(p*signal,n*signal)
#     double precision, intent(inout), dimension(:,:,:) :: thetahatvar
#     !f2py depend(p) dimension(p*signal,p*signal,n*signal)
#     double precision, intent(in), dimension(:,:,:) :: zorig
#     !f2py depend(p) dimension(ldlsignal*p,ldlsignal*m,ldlsignal*((n-1)*zorigtv+1))
#     double precision, dimension(m,m) :: linf,l0
#     double precision, dimension(m,m) :: nrec,nrec1,nrec2,im,mm,mm2
#     double precision, dimension(m) :: rrec,rrec1,rhelp, help
#     double precision, dimension(m,r) :: mr, mr2
#     double precision, dimension(p,m) :: pm
#     !f2py depend(p) dimension(p,m)
#     double precision, dimension(p,n) ::  ftinv
#     !f2py depend(p) dimension(p,n)
#     double precision, dimension(p,d) ::  finfinv
#     !f2py depend(p) dimension(p,d)
#     double precision, external :: ddot
#     external dgemm, dsymm, dgemv, dsymv, dger
#
#     if(aug.EQ.1 .AND. dist.EQ.1) then
#         do i = 1, p
#             do t = 1, n
#                 epshatvar(i,t) =  ht(i,i,(t-1)*timevar(2)+1)
#             end do
#         end do
#     end if
#
#
#     ftinv = 1.0d0/ft
#     finfinv = 1.0d0/finf
#
#     im = 0.0d0
#     do i = 1, m
#         im(i,i) = 1.0d0
#     end do
#
#     rrec = 0.0d0
#     nrec = 0.0d0
#     nt(:,:,n+1) = 0.0d0 !t goes from n+1 to 1, not from n to 0 !
#     rt(:,n+1) = 0.0d0
#
#
#     do t = n, d+1, -1 !do until diffuse starts
#
#
#         do i = p, 1 , -1
#             if(ymiss(t,i).EQ.0) then
#                 if(ft(i,t) .GT. 0.0d0) then
#                     if(aug.EQ.1 .AND. dist.EQ.1) then
#                         epshat(i,t) = ht(i,i,(t-1)*timevar(2)+1)*ftinv(i,t)*(vt(i,t)-ddot(m,kt(:,i,t),1,rrec,1))
#                         call dgemv('n',m,m,ftinv(i,t)**2, nrec,m,kt(:,i,t),1,0.0d0,rhelp,1)
#                         epshatvar(i,t) = ht(i,i,(t-1)*timevar(2)+1)-(ht(i,i,(t-1)*timevar(2)+1)**2)*&
#                         (ftinv(i,t)+ddot(m,kt(:,i,t),1,rhelp,1))
#                     end if
#
#                     l0 = im
#                     call dger(m,m,-ftinv(i,t),kt(:,i,t),1,zt(i,:,(t-1)*timevar(1)+1),1,l0,m)
#                     call dgemv('t',m,m,1.0d0,l0,m,rrec,1,0.0d0,rhelp,1)
#                     rrec = rhelp + vt(i,t)*ftinv(i,t)*zt(i,:,(t-1)*timevar(1)+1)
#
#                     call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,0.0d0,nrec,m)
#                     call dger(m,m,ftinv(i,t),zt(i,:,(t-1)*timevar(1)+1),1,zt(i,:,(t-1)*timevar(1)+1),1,nrec,m)
#                 end if
#             end if
#         end do
#
#         rt(:,t) =rrec
#         nt(:,:,t) = nrec !n_t-1 = n_t,0
#
#         if(t.GT. 1) then
#             call dgemv('t',m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,rrec,1,0.0d0,rhelp,1)
#             rrec = rhelp
#             call dsymm('l','u',m,m,1.0d0,nrec,m,tt(:,:,(t-2)*timevar(3)+1),m,0.0d0,mm,m)
#             call dgemm('t','n',m,m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,mm,m,0.0d0,nrec,m)
#         end if
#
#     end do
#
#
#     if(d.GT.0) then
#         t=d
#         rt0(:,d+1)=rt(:,d+1)
#         nt0(:,:,d+1) =  nt(:,:,d+1)
#
#         do i = p, (j+1) , -1
#             if(ymiss(t,i).EQ.0) then
#                 if(ft(i,t) .GT. 0.0d0) then
#                     if(aug .EQ. 1 .AND. dist.EQ.1) then
#                         epshat(i,t) = ht(i,i,(t-1)*timevar(2)+1)*ftinv(i,t)*(vt(i,t)-ddot(m,kt(:,i,t),1,rrec,1))
#                         call dgemv('n',m,m,ftinv(i,t)**2,nrec,m,kt(:,i,t),1,0.0d0,rhelp,1)
#                         epshatvar(i,t) = ht(i,i,(t-1)*timevar(2)+1)-(ht(i,i,(t-1)*timevar(2)+1)**2)*&
#                         (ftinv(i,t)+ddot(m,kt(:,i,t),1,rhelp,1))
#                     end if
#
#                     l0 = im
#                     call dger(m,m,-ftinv(i,t),kt(:,i,t),1,zt(i,:,(t-1)*timevar(1)+1),1,l0,m)
#                     call dgemv('t',m,m,1.0d0,l0,m,rrec,1,0.0d0,rhelp,1)
#                     rrec = rhelp + vt(i,t)*ftinv(i,t)*zt(i,:,(t-1)*timevar(1)+1)
#
#                     call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,0.0d0,nrec,m)
#                     call dgemm('t','n',m,m,1,1.0d0,zt(i,:,(t-1)*timevar(1)+1),&
#                     1,zt(i,:,(t-1)*timevar(1)+1),1,0.0d0,mm,m)
#                     nrec = mm*ftinv(i,t)+nrec
#                 end if
#             end if
#         end do
#
#         rrec1 = 0.0d0
#         nrec1 = 0.0d0
#         nrec2 = 0.0d0
#
#         do i = j, 1, -1
#             if(ymiss(t,i).EQ.0) then
#                 if(finf(i,t) .GT. 0.0d0) then
#                     if(aug .EQ. 1 .AND. dist.EQ.1) then
#                         epshat(i,t) = -ht(i,i,(t-1)*timevar(2)+1)*ddot(m,kinf(:,i,t),1,rrec,1)*finfinv(i,t)
#                         call dgemv('n',m,m,1.0d0,nrec,m,kinf(:,i,t),1,0.0d0,rhelp,1)
#                         epshatvar(i,t) = ht(i,i,(t-1)*timevar(2)+1)-(ht(i,i,(t-1)*timevar(2)+1)**2)*&
#                         ddot(m,kinf(:,i,t),1,rhelp,1)*finfinv(i,t)**2
#                     end if
#
#
#                     linf = im
#                     call dger(m,m,-finfinv(i,t),kinf(:,i,t),1,zt(i,:,(t-1)*timevar(1)+1),1,linf,m)
#
#                     rhelp = kinf(:,i,t)*ft(i,t)*finfinv(i,t) - kt(:,i,t)
#                     l0=0.0d0
#                     call dger(m,m,finfinv(i,t),rhelp,1,zt(i,:,(t-1)*timevar(1)+1),1,l0,m)
#
#                     call dgemv('t',m,m,1.0d0,linf,m,rrec1,1,0.0d0,rhelp,1) !rt1
#                     rrec1 = rhelp
#                     call dgemv('t',m,m,1.0d0,l0,m,rrec,1,1.0d0,rrec1,1)
#                     rrec1 = rrec1 + vt(i,t)*finfinv(i,t)*zt(i,:,(t-1)*timevar(1)+1)
#
#                     call dgemv('t',m,m,1.0d0,linf,m,rrec,1,0.0d0,rhelp,1) !rt0
#                     rrec = rhelp
#
#                     call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec2,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,0.0d0,nrec2,m)
#                     call dger(m,m,-ft(i,t)*finfinv(i,t)**2.0d0,zt(i,:,(t-1)*timevar(1)+1)&
#                     ,1,zt(i,:,(t-1)*timevar(1)+1),1,nrec2,m)
#                     call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,1.0d0,nrec2,m)
#
#                     call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec1,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,0.0d0,mm2,m)
#                     nrec2 = nrec2 +mm2 + transpose(mm2)
#
#                     call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec1,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,0.0d0,nrec1,m)
#
#                     call dger(m,m,finfinv(i,t),zt(i,:,(t-1)*timevar(1)+1),1,zt(i,:,(t-1)*timevar(1)+1),1,nrec1,m)
#                     call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,1.0d0,nrec1,m)
#
#                     call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec,m,0.0d0,mm,m)
#                     call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,0.0d0,nrec,m)
#
#                 else
#                     if(ft(i,t).GT.0.0d0) then
#                         if(aug .EQ. 1 .AND. dist.EQ.1) then
#                             epshat(i,t) = ht(i,i,(t-1)*timevar(2)+1)*(vt(i,t)*ftinv(i,t)-&
#                             ddot(m,kt(:,i,t),1,rrec,1)*ftinv(i,t))
#                             call dgemv('n',m,m,1.0d0,nrec,m,kt(:,i,t),1,0.0d0,rhelp,1)
#                             epshatvar(i,t) = ht(i,i,(t-1)*timevar(2)+1)-(ht(i,i,(t-1)*timevar(2)+1)**2)*&
#                             (ftinv(i,t)+ddot(m,kt(:,i,t),1,rhelp,1)*ftinv(i,t)**2)
#                         end if
#                         l0 = im
#                         call dger(m,m,-ftinv(i,t),kt(:,i,t),1,zt(i,:,(t-1)*timevar(1)+1),1,l0,m) !lt = I -Kt*Z/Ft
#
#                         call dgemv('t',m,m,1.0d0,l0,m,rrec,1,0.0d0,rhelp,1) !r0
#                         rrec = rhelp + vt(i,t)*ftinv(i,t)*zt(i,:,(t-1)*timevar(1)+1)   !!r0 = Z'vt/Ft - Lt'r0
#
#                         call dgemv('t',m,m,1.0d0,l0,m,rrec1,1,0.0d0,rhelp,1) !r1
#                         rrec1 = rhelp
#
#
#                         call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                         call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,0.0d0,nrec,m)
#                         call dger(m,m,ftinv(i,t),zt(i,:,(t-1)*timevar(1)+1),1,&
#                         zt(i,:,(t-1)*timevar(1)+1),1,nrec,m)
#                         call dgemm('n','n',m,m,m,1.0d0,nrec1,m,l0,m,0.0d0,mm,m)
#                         nrec1 = mm
#                         call dgemm('n','n',m,m,m,1.0d0,nrec2,m,l0,m,0.0d0,mm,m)
#                         nrec2 = mm
#                     end if
#                 end if
#             end if
#         end do
#         rt0(:,t) = rrec
#         rt1(:,t) = rrec1
#         nt0(:,:,t) = nrec
#         nt1(:,:,t) = nrec1
#         nt2(:,:,t) = nrec2
#
#
#
#         if(t.GT.1) then
#             call dgemv('t',m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,rrec,1,0.0d0,rhelp,1)
#             rrec = rhelp
#             call dgemv('t',m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,rrec1,1,0.0d0,rhelp,1)
#             rrec1 = rhelp
#             call dgemm('t','n',m,m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,nrec,m,0.0d0,mm,m)
#             call dgemm('n','n',m,m,m,1.0d0,mm,m,tt(:,:,(t-2)*timevar(3)+1),m,0.0d0,nrec,m)
#             call dgemm('t','n',m,m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,nrec1,m,0.0d0,mm,m)
#             call dgemm('n','n',m,m,m,1.0d0,mm,m,tt(:,:,(t-2)*timevar(3)+1),m,0.0d0,nrec1,m)
#             call dgemm('t','n',m,m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,nrec2,m,0.0d0,mm,m)
#             call dgemm('n','n',m,m,m,1.0d0,mm,m,tt(:,:,(t-2)*timevar(3)+1),m,0.0d0,nrec2,m)
#         end if
#
#         do t=(d-1), 1, -1
#
#             do i = p, 1, -1
#                 if(ymiss(t,i).EQ.0) then
#                     if(finf(i,t).GT. 0.0d0) then
#                         if(aug .EQ. 1 .AND. dist.EQ.1) then
#                             epshat(i,t) = -ht(i,i,(t-1)*timevar(2)+1)*ddot(m,kinf(:,i,t),1,rrec,1)*finfinv(i,t)
#                             call dgemv('n',m,m,1.0d0,nrec,m,kinf(:,i,t),1,0.0d0,rhelp,1)
#                             epshatvar(i,t) = ht(i,i,(t-1)*timevar(2)+1)-(ht(i,i,(t-1)*timevar(2)+1)**2)*&
#                             ddot(m,kinf(:,i,t),1,rhelp,1)*finfinv(i,t)**2
#                         end if
#
#                         linf = im
#                         call dger(m,m,-finfinv(i,t),kinf(:,i,t),1,zt(i,:,(t-1)*timevar(1)+1),1,linf,m)
#
#                         rhelp = kinf(:,i,t)*ft(i,t)*finfinv(i,t) - kt(:,i,t)
#                         l0=0.0d0
#                         call dger(m,m,finfinv(i,t),rhelp,1,zt(i,:,(t-1)*timevar(1)+1),1,l0,m)
#
#                         call dgemv('t',m,m,1.0d0,linf,m,rrec1,1,0.0d0,rhelp,1) !rt1
#                         rrec1 = rhelp
#                         call dgemv('t',m,m,1.0d0,l0,m,rrec,1,1.0d0,rrec1,1)
#                         rrec1 = rrec1 + vt(i,t)*finfinv(i,t)*zt(i,:,(t-1)*timevar(1)+1)
#
#                         call dgemv('t',m,m,1.0d0,linf,m,rrec,1,0.0d0,rhelp,1) !rt0
#                         rrec = rhelp
#
#
#                         call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec2,m,0.0d0,mm,m)
#                         call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,0.0d0,nrec2,m)
#                         call dger(m,m,-ft(i,t)*finfinv(i,t)**2.0d0,zt(i,:,(t-1)*timevar(1)+1)&
#                         ,1,zt(i,:,(t-1)*timevar(1)+1),1,nrec2,m)
#                         call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                         call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,1.0d0,nrec2,m)
#
#                         call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec1,m,0.0d0,mm,m)
#                         call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,0.0d0,mm2,m)
#                         nrec2 = nrec2 +mm2 + transpose(mm2)
#
#                         call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec1,m,0.0d0,mm,m)
#                         call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,0.0d0,nrec1,m)
#
#                         call dger(m,m,finfinv(i,t),zt(i,:,(t-1)*timevar(1)+1),1,zt(i,:,(t-1)*timevar(1)+1),1,nrec1,m)
#                         call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                         call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,1.0d0,nrec1,m)
#
#                         call dgemm('t','n',m,m,m,1.0d0,linf,m,nrec,m,0.0d0,mm,m)
#                         call dgemm('n','n',m,m,m,1.0d0,mm,m,linf,m,0.0d0,nrec,m)
#
#                     else
#                         if(ft(i,t).GT.0.0d0) then
#                             if(aug .EQ. 1 .AND. dist.EQ.1) then
#                                 epshat(i,t) = ht(i,i,(t-1)*timevar(2)+1)*(vt(i,t)*ftinv(i,t)-&
#                                 ddot(m,kt(:,i,t),1,rrec,1)*ftinv(i,t))
#                                 call dgemv('n',m,m,1.0d0,nrec,m,kt(:,i,t),1,0.0d0,rhelp,1)
#                                 epshatvar(i,t) = ht(i,i,(t-1)*timevar(2)+1)-(ht(i,i,(t-1)*timevar(2)+1)**2)*&
#                                 (ftinv(i,t)+ddot(m,kt(:,i,t),1,rhelp,1)*ftinv(i,t)**2 )
#                             end if
#                             l0 = im
#                             call dger(m,m,-ftinv(i,t),kt(:,i,t),1,zt(i,:,(t-1)*timevar(1)+1),1,l0,m) !lt = I -Kt*Z/Ft
#
#                             call dgemv('t',m,m,1.0d0,l0,m,rrec,1,0.0d0,rhelp,1) !r0
#                             rrec = rhelp + vt(i,t)*ftinv(i,t)*zt(i,:,(t-1)*timevar(1)+1)   !!r0 = Z'vt/Ft - Lt'r0
#
#                             call dgemv('t',m,m,1.0d0,l0,m,rrec1,1,0.0d0,rhelp,1) !r1
#                             rrec1 = rhelp
#
#                             call dgemm('t','n',m,m,m,1.0d0,l0,m,nrec,m,0.0d0,mm,m)
#                             call dgemm('n','n',m,m,m,1.0d0,mm,m,l0,m,0.0d0,nrec,m)
#                             call dger(m,m,ftinv(i,t),zt(i,:,(t-1)*timevar(1)+1),1,&
#                             zt(i,:,(t-1)*timevar(1)+1),1,nrec,m)
#                             call dgemm('n','n',m,m,m,1.0d0,nrec1,m,l0,m,0.0d0,mm,m)
#                             nrec1 = mm
#                             call dgemm('n','n',m,m,m,1.0d0,nrec2,m,l0,m,0.0d0,mm,m)
#                             nrec2 = mm
#                         end if
#                     end if
#                 end if
#             end do
#
#
#             rt0(:,t) = rrec
#             rt1(:,t) = rrec1
#             nt0(:,:,t) = nrec
#             nt1(:,:,t) = nrec1
#             nt2(:,:,t) = nrec2
#
#
#             if(t.GT.1) then
#                 call dgemv('t',m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,rrec,1,0.0d0,rhelp,1)
#                 rrec = rhelp
#                 call dgemv('t',m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,rrec1,1,0.0d0,rhelp,1)
#                 rrec1 = rhelp
#                 call dgemm('t','n',m,m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,nrec,m,0.0d0,mm,m)
#                 call dgemm('n','n',m,m,m,1.0d0,mm,m,tt(:,:,(t-2)*timevar(3)+1),m,0.0d0,nrec,m)
#                 call dgemm('t','n',m,m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,nrec1,m,0.0d0,mm,m)
#                 call dgemm('n','n',m,m,m,1.0d0,mm,m,tt(:,:,(t-2)*timevar(3)+1),m,0.0d0,nrec1,m)
#                 call dgemm('t','n',m,m,m,1.0d0,tt(:,:,(t-2)*timevar(3)+1),m,nrec2,m,0.0d0,mm,m)
#                 call dgemm('n','n',m,m,m,1.0d0,mm,m,tt(:,:,(t-2)*timevar(3)+1),m,0.0d0,nrec2,m)
#             end if
#
#
#         end do
#     end if
#
#     if(state.EQ.1) then
#         do t = 1, d
#             ahat(:,t) = at(:,t)
#             call dsymv('u',m,1.0d0,pt(:,:,t),m,rt0(:,t),1,1.0d0,ahat(:,t),1)
#             call dsymv('u',m,1.0d0,pinf(:,:,t),m,rt1(:,t),1,1.0d0,ahat(:,t),1)
#
#             vvt(:,:,t) = pt(:,:,t)
#             call dsymm('l','u',m,m,1.0d0,pt(:,:,t),m,nt0(:,:,t),m,0.0d0,mm,m)
#             call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,1.0d0,vvt(:,:,t),m)
#             call dsymm('l','u',m,m,1.0d0,pinf(:,:,t),m,nt1(:,:,t),m,0.0d0,mm,m)
#             call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,0.0d0,mm2,m)
#
#             vvt(:,:,t) = vvt(:,:,t) + mm2 + transpose(mm2)
#             call dsymm('l','u',m,m,1.0d0,pinf(:,:,t),m,nt2(:,:,t),m,0.0d0,mm,m)
#             call dsymm('r','u',m,m,-1.0d0,pinf(:,:,t),m,mm,m,1.0d0,vvt(:,:,t),m)
#             ! force symmetry
#             do k1 = 1,m
#               do k2 = k1,m
#                 vvt(k2,k1,t) = vvt(k1,k2,t)
#               end do
#             end do
#             ! remove clear rounding errors (negative variances)
#             do i=1, m
#               if (vvt(i,i,t) .LE. 0) then
#                 vvt(i,:,t) = 0.0d0
#                 vvt(:,i,t) = 0.0d0
#               end if
#             end do
#         end do
#         do t = d+1, n
#             ahat(:,t) = at(:,t)
#             call dsymv('u',m,1.0d0,pt(:,:,t),m,rt(:,t),1,1.0d0,ahat(:,t),1)
#             call dsymm('l','u',m,m,1.0d0,pt(:,:,t),m,nt(:,:,t),m,0.0d0,mm,m)
#             mm = im - mm
#             call dsymm('r','u',m,m,1.0d0,pt(:,:,t),m,mm,m,0.0d0,vvt(:,:,t),m)
#
#             ! force symmetry
#             do k1 = 1,m
#               do k2 = k1,m
#                 vvt(k2,k1,t) = vvt(k1,k2,t)
#               end do
#             end do
#             ! remove clear rounding errors (negative variances)
#             do i=1, m
#               if (vvt(i,i,t) .LE. 0) then
#                 vvt(i,:,t) = 0.0d0
#                 vvt(:,i,t) = 0.0d0
#               end if
#             end do
#         end do
#     end if
#
#     if(dist.EQ.1) then
#         do t = 1, d
#             call dgemv('t',m,r,1.0d0,rtv(:,:,(t-1)*timevar(4)+1),m,rt0(:,t+1),1,0.0d0,help,1)
#             call dsymv('u',r,1.0d0,qt(:,:,(t-1)*timevar(5)+1),r,help,1,0.0d0,etahat(:,t),1)
#             etahatvar(:,:,t) = qt(:,:,(t-1)*timevar(5)+1)
#             call dsymm('r','u',m,r,1.0d0,qt(:,:,(t-1)*timevar(5)+1),r,rtv(:,:,(t-1)*timevar(4)+1),m,0.0d0,mr,m)
#             call dsymm('l','u',m,r,1.0d0,nt0(:,:,t+1),m,mr,m,0.0d0,mr2,m)
#             call dgemm('t','n',r,r,m,-1.0d0,mr,m,mr2,m,1.0d0,etahatvar(:,:,t),r)
#
#             ! remove clear rounding errors (negative variances)
#             do i=1, r
#               if (etahatvar(i,i,t) .LE. 0) then
#                 etahatvar(i,:,t) = 0.0d0
#                 etahatvar(:,i,t) = 0.0d0
#               end if
#             end do
#         end do
#         do t = d+1, n
#             call dgemv('t',m,r,1.0d0,rtv(:,:,(t-1)*timevar(4)+1),m,rt(:,t+1),1,0.0d0,help,1)
#             call dsymv('u',r,1.0d0,qt(:,:,(t-1)*timevar(5)+1),r,help,1,0.0d0,etahat(:,t),1)
#             etahatvar(:,:,t) = qt(:,:,(t-1)*timevar(5)+1)
#             call dsymm('r','u',m,r,1.0d0,qt(:,:,(t-1)*timevar(5)+1),r,rtv(:,:,(t-1)*timevar(4)+1),m,0.0d0,mr,m)
#             call dsymm('l','u',m,r,1.0d0,nt(:,:,t+1),m,mr,m,0.0d0,mr2,m)
#             call dgemm('t','n',r,r,m,-1.0d0,mr,m,mr2,m,1.0d0,etahatvar(:,:,t),r)
#             ! remove clear rounding errors (negative variances)
#             do i=1, r
#               if (etahatvar(i,i,t) .LE. 0) then
#                 etahatvar(i,:,t) = 0.0d0
#                 etahatvar(:,i,t) = 0.0d0
#               end if
#             end do
#         end do
#     end if
#
#     if(signal.EQ.1) then
#         if(ldlsignal .EQ. 1) then
#             if(state .EQ. 1) then
#                 do t = 1, n
#                     call dgemv('n',p,m,1.0d0,zorig(:,:,(t-1)*zorigtv+1),p,ahat(:,t),1,0.0d0,thetahat(:,t),1)
#                     call dsymm('r','u',p,m,1.0d0,vvt(:,:,t),m,zorig(:,:,(t-1)*zorigtv+1),p,0.0d0,pm,p)
#                     call dgemm('n','t',p,p,m,1.0d0,pm,p,zorig(:,:,(t-1)*zorigtv+1),p,0.0d0,thetahatvar(:,:,t),p)
#                 end do
#             else
#                 do t = 1, d
#                     rrec = at(:,t)
#                     call dsymv('u',m,1.0d0,pt(:,:,t),m,rt0(:,t),1,1.0d0,rrec,1)
#                     call dsymv('u',m,1.0d0,pinf(:,:,t),m,rt1(:,t),1,1.0d0,rrec,1)
#                     call dgemv('n',p,m,1.0d0,zorig(:,:,(t-1)*zorigtv+1),p,rrec,1,0.0d0,thetahat(:,t),1)
#
#                     nrec = pt(:,:,t)
#                     call dsymm('l','u',m,m,1.0d0,pt(:,:,t),m,nt0(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,1.0d0,nrec,m)
#                     call dsymm('l','u',m,m,1.0d0,pinf(:,:,t),m,nt1(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,0.0d0,mm2,m)
#                     nrec = nrec + mm2 + transpose(mm2)
#                     call dsymm('l','u',m,m,1.0d0,pinf(:,:,t),m,nt2(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pinf(:,:,t),m,mm,m,1.0d0,nrec,m)
#                     call dsymm('r','u',p,m,1.0d0,nrec,m,zorig(:,:,(t-1)*zorigtv+1),p,0.0d0,pm,p)
#                     call dgemm('n','t',p,p,m,1.0d0,pm,p,zorig(:,:,(t-1)*zorigtv+1),p,0.0d0,thetahatvar(:,:,t),p)
#                     ! remove clear rounding errors (negative variances)
#                     do i=1, p
#                       if (thetahatvar(i,i,t) .LE. 0) then
#                         thetahatvar(i,:,t) = 0.0d0
#                         thetahatvar(:,i,t) = 0.0d0
#                       end if
#                     end do
#                 end do
#                 do t = d+1, n
#                     rrec = at(:,t)
#                     call dsymv('u',m,1.0d0,pt(:,:,t),m,rt(:,t),1,1.0d0,rrec,1)
#                     call dgemv('n',p,m,1.0d0,zorig(:,:,(t-1)*zorigtv+1),p,rrec,1,0.0d0,thetahat(:,t),1)
#                     nrec = pt(:,:,t)
#                     call dsymm('l','u',m,m,1.0d0,pt(:,:,t),m,nt(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,1.0d0,nrec,m)
#                     call dsymm('r','u',p,m,1.0d0,nrec,m,zorig(:,:,(t-1)*zorigtv+1),p,0.0d0,pm,p)
#                     call dgemm('n','t',p,p,m,1.0d0,pm,p,zorig(:,:,(t-1)*zorigtv+1),p,0.0d0,thetahatvar(:,:,t),p)
#                     ! remove clear rounding errors (negative variances)
#                     do i=1, p
#                       if (thetahatvar(i,i,t) .LE. 0) then
#                         thetahatvar(i,:,t) = 0.0d0
#                         thetahatvar(:,i,t) = 0.0d0
#                       end if
#                     end do
#                 end do
#             end if
#         else
#
#             if(state .EQ. 1) then
#                 do t = 1, n
#                     call dgemv('n',p,m,1.0d0,zt(:,:,(t-1)*timevar(1)+1),p,ahat(:,t),1,0.0d0,thetahat(:,t),1)
#                     call dsymm('r','u',p,m,1.0d0,vvt(:,:,t),m,zt(:,:,(t-1)*timevar(1)+1),p,0.0d0,pm,p)
#                     call dgemm('n','t',p,p,m,1.0d0,pm,p,zt(:,:,(t-1)*timevar(1)+1),p,0.0d0,thetahatvar(:,:,t),p)
#                 end do
#             else
#                 do t = 1, d
#                     rrec = at(:,t)
#                     call dsymv('u',m,1.0d0,pt(:,:,t),m,rt0(:,t),1,1.0d0,rrec,1)
#                     call dsymv('u',m,1.0d0,pinf(:,:,t),m,rt1(:,t),1,1.0d0,rrec,1)
#                     call dgemv('n',p,m,1.0d0,zt(:,:,(t-1)*timevar(1)+1),p,rrec,1,0.0d0,thetahat(:,t),1)
#
#                     nrec = pt(:,:,t)
#                     call dsymm('l','u',m,m,1.0d0,pt(:,:,t),m,nt0(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,1.0d0,nrec,m)
#                     call dsymm('l','u',m,m,1.0d0,pinf(:,:,t),m,nt1(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,0.0d0,mm2,m)
#                     nrec = nrec + mm2 + transpose(mm2)
#                     call dsymm('l','u',m,m,1.0d0,pinf(:,:,t),m,nt2(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pinf(:,:,t),m,mm,m,1.0d0,nrec,m)
#                     call dsymm('r','u',p,m,1.0d0,nrec,m,zt(:,:,(t-1)*timevar(1)+1),p,0.0d0,pm,p)
#                     call dgemm('n','t',p,p,m,1.0d0,pm,p,zt(:,:,(t-1)*timevar(1)+1),p,0.0d0,thetahatvar(:,:,t),p)
#                     ! remove clear rounding errors (negative variances)
#                     do i=1, p
#                       if (thetahatvar(i,i,t) .LE. 0) then
#                         thetahatvar(i,:,t) = 0.0d0
#                         thetahatvar(:,i,t) = 0.0d0
#                       end if
#                     end do
#                 end do
#                 do t = d+1, n
#                     rrec = at(:,t)
#                     call dsymv('u',m,1.0d0,pt(:,:,t),m,rt(:,t),1,1.0d0,rrec,1)
#                     call dgemv('n',p,m,1.0d0,zt(:,:,(t-1)*timevar(1)+1),p,rrec,1,0.0d0,thetahat(:,t),1)
#                     nrec = pt(:,:,t)
#                     call dsymm('l','u',m,m,1.0d0,pt(:,:,t),m,nt(:,:,t),m,0.0d0,mm,m)
#                     call dsymm('r','u',m,m,-1.0d0,pt(:,:,t),m,mm,m,1.0d0,nrec,m)
#                     call dsymm('r','u',p,m,1.0d0,nrec,m,zt(:,:,(t-1)*timevar(1)+1),p,0.0d0,pm,p)
#                     call dgemm('n','t',p,p,m,1.0d0,pm,p,zt(:,:,(t-1)*timevar(1)+1),p,0.0d0,thetahatvar(:,:,t),p)
#                     ! remove clear rounding errors (negative variances)
#                     do i=1, p
#                       if (thetahatvar(i,i,t) .LE. 0) then
#                         thetahatvar(i,:,t) = 0.0d0
#                         thetahatvar(:,i,t) = 0.0d0
#                       end if
#                     end do
#                 end do
#             end if
#         end if
#     end if
#
# end subroutine gsmoothall

# %%
import gsmoothall

# %%
print(gsmoothall.gsmoothall.__doc__)
# Out:
# gsmoothall(ymiss,timevar,zt,ht,tt,rtv,qt,p,r,j,at,pt,vt,ft,kt,rt,rt0,rt1,nt,nt0,nt1,nt2,pinf,kinf,finf,ahat,vvt,epshat,epshatvar,etahat,etahatvar,thetahat,thetahatvar,ldlsignal,zorig,zorigtv,aug,state,dist,signal,[n,m,d])
#
# Wrapper for ``gsmoothall``.
#
# Parameters
# ----------
# ymiss : input rank-2 array('i') with bounds (f2py_ymiss_d0,f2py_ymiss_d1)
# timevar : input rank-1 array('i') with bounds (5)
# zt : input rank-3 array('d') with bounds (f2py_zt_d0,f2py_zt_d1,f2py_zt_d2)
# ht : input rank-3 array('d') with bounds (f2py_ht_d0,f2py_ht_d1,f2py_ht_d2)
# tt : input rank-3 array('d') with bounds (f2py_tt_d0,f2py_tt_d1,f2py_tt_d2)
# rtv : input rank-3 array('d') with bounds (f2py_rtv_d0,f2py_rtv_d1,f2py_rtv_d2)
# qt : input rank-3 array('d') with bounds (f2py_qt_d0,f2py_qt_d1,f2py_qt_d2)
# p : input int
# r : input int
# j : input int
# at : input rank-2 array('d') with bounds (m,n + 1)
# pt : input rank-3 array('d') with bounds (m,m,n + 1)
# vt : input rank-2 array('d') with bounds (f2py_vt_d0,f2py_vt_d1)
# ft : input rank-2 array('d') with bounds (f2py_ft_d0,f2py_ft_d1)
# kt : input rank-3 array('d') with bounds (f2py_kt_d0,f2py_kt_d1,f2py_kt_d2)
# rt : in/output rank-2 array('d') with bounds (m,n + 1)
# rt0 : in/output rank-2 array('d') with bounds (m,d + 1)
# rt1 : in/output rank-2 array('d') with bounds (m,d + 1)
# nt : in/output rank-3 array('d') with bounds (m,m,n + 1)
# nt0 : in/output rank-3 array('d') with bounds (m,m,d + 1)
# nt1 : in/output rank-3 array('d') with bounds (m,m,d + 1)
# nt2 : in/output rank-3 array('d') with bounds (m,m,d + 1)
# pinf : input rank-3 array('d') with bounds (m,m,d + 1)
# kinf : input rank-3 array('d') with bounds (f2py_kinf_d0,f2py_kinf_d1,f2py_kinf_d2)
# finf : input rank-2 array('d') with bounds (f2py_finf_d0,f2py_finf_d1)
# ahat : in/output rank-2 array('d') with bounds (f2py_ahat_d0,f2py_ahat_d1)
# vvt : in/output rank-3 array('d') with bounds (m,m,n)
# epshat : in/output rank-2 array('d') with bounds (f2py_epshat_d0,f2py_epshat_d1)
# epshatvar : in/output rank-2 array('d') with bounds (f2py_epshatvar_d0,f2py_epshatvar_d1)
# etahat : in/output rank-2 array('d') with bounds (f2py_etahat_d0,f2py_etahat_d1)
# etahatvar : in/output rank-3 array('d') with bounds (f2py_etahatvar_d0,f2py_etahatvar_d1,f2py_etahatvar_d2)
# thetahat : in/output rank-2 array('d') with bounds (f2py_thetahat_d0,f2py_thetahat_d1)
# thetahatvar : in/output rank-3 array('d') with bounds (f2py_thetahatvar_d0,f2py_thetahatvar_d1,f2py_thetahatvar_d2)
# ldlsignal : input int
# zorig : input rank-3 array('d') with bounds (f2py_zorig_d0,f2py_zorig_d1,f2py_zorig_d2)
# zorigtv : input int
# aug : input int
# state : input int
# dist : input int
# signal : input int
#
# Other Parameters
# ----------------
# n : input int, optional
#     Default: (shape(at,1)-1)
# m : input int, optional
#     Default: shape(at,0)
# d : input int, optional
#     Default: (shape(rt0,1)-1)
